# %%
# Import dependencies
import pandas as pd
from pymongo import MongoClient

# %% [markdown]
# # Extract Datasets

# %%
# Set the column width for each dataframe
pd.options.display.max_colwidth = 400

#Read the csv file into a dataframe for the Sport car price csv
sport_car = pd.read_csv("Resources/Sport car price.csv")

#Display the dataframe
sport_car.head()
# Out:
#       Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0      Porsche       911  2022               3        379            331
# 1  Lamborghini   Huracan  2021             5.2        630            443
# 2      Ferrari   488 GTB  2022             3.9        661            561
# 3         Audi        R8  2022             5.2        562            406
# 4      McLaren      720S  2021               4        710            568
#
#   0-60 MPH Time (seconds) Price (in USD)
# 0                       4        101,200
# 1                     2.8        274,390
# 2                       3        333,750
# 3                     3.2        142,700
# 4                     2.7        298,000

# %%
#Read the csv file into a dataframe for the Sport car noise specifications csv 
car_noise = pd.read_csv("Resources/car_noise_new.csv")

#Display the dataframe
car_noise.head()
# Out:
#    Unnamed: 0   brand model           spec    year  dB_at_idle  dB_at_50kmh  \
# 0           0  Abarth   500  1.4 16v T-Jet  2008.0        47.3         58.2
# 1           1  Abarth   595   Competizione  2017.0        49.9         65.7
# 2           2   Acura   MDX         3.5 V6  2013.0        41.7         51.7
# 3           3   Acura   RDX         3.5 V6  2012.0        43.0         54.4
# 4           4   Acura    RL         3.7 V6  2009.0        43.6         55.5
#
#    dB_at_80kmh  dB_at_100kmh  dB_at_120kmh  ...  model_height_in_cqa  \
# 0         67.0          70.2          72.9  ...                  NaN
# 1         69.0          72.3          73.1  ...                  NaN
# 2         57.9          61.2          64.0  ...                 68.2
# 3         61.5          65.5          67.7  ...                 65.1
# 4         63.0          66.9          70.2  ...                 57.5
#
#    model_wheelbase_in_cqa  model_mpg_hwy_cqa model_mpg_city_cqa  \
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                   108.3               27.0               19.0
# 3                   104.3               22.0               17.0
# 4                   110.6               22.0               16.0
#
#   model_mpg_mixed_cqa model_fuel_cap_g_cqa  make_display_cqa make_country_cqa  \
# 0                 NaN                  NaN               NaN              NaN
# 1                 NaN                  NaN               NaN              NaN
# 2                 NaN                 20.9             Acura              USA
# 3                 NaN                 18.0             Acura              USA
# 4                18.0                 19.3             Acura              USA
#
#   ExtColors_cqa  IntColors_cqa
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
#
# [5 rows x 72 columns]

# %% [markdown]
# # Transform Dataset 1

# %%
# Identify the datatype of each column
sport_car.dtypes
# Out:
# Car Make                   object
# Car Model                  object
# Year                        int64
# Engine Size (L)            object
# Horsepower                 object
# Torque (lb-ft)             object
# 0-60 MPH Time (seconds)    object
# Price (in USD)             object
# dtype: object

# %%
#Find all engine sizes categories 
sport_car["Engine Size (L)"].unique()
# Out:
# array(['3', '5.2', '3.9', '4', '4.4', '6.2', '3.8', '8', '5', '3.5',
#        '4.7', '2', '2.9', '6', 'Electric', '6.5', '3.7', 'Electric Motor',
#        '2.5', '1.5 + Electric', '6.8', '8.4', nan, '6.6', '7', '1.7',
#        '3.3', '-', '6.7', '1.8', 'Electric (tri-motor)', '5.5',
#        'Electric (93 kWh)', 'Electric (100 kWh)', 'Hybrid (4.0)', '4.6',
#        '3.6', '1.5', 'Hybrid', '5.7', '2.0 (Electric)', '4.0 (Hybrid)',
#        '0', '6.4', '6.3', '2.3'], dtype=object)

# %%
len(sport_car)
# Out:
# 958

# %%
#Find and remove all occurances of electric and hybrid vehicles, for which engine size is not listed
sport_car =sport_car.loc[sport_car["Engine Size (L)"]!= "Electric"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "Electric Motor"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "1.5 + Electric"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= None]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "Electric (tri-motor)"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "Electric (93 kWh)"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "Electric (100 kWh)"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "Hybrid (4.0)"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "Hybrid"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "2.0 (Electric)"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "4.0 (Hybrid)"]
sport_car = sport_car.loc[sport_car["Engine Size (L)"]!= "-"]

#Check number of rows remaining in dataframe
len(sport_car)
# Out:
# 958

# %%
#Remove Commas in the "Price (in USD) column" to ease conversion into floats
sport_car["Price (in USD)"]= sport_car["Price (in USD)"].str.replace(',','').astype(float)
sport_car.head()
# Out:
#       Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0      Porsche       911  2022               3        379            331
# 1  Lamborghini   Huracan  2021             5.2        630            443
# 2      Ferrari   488 GTB  2022             3.9        661            561
# 3         Audi        R8  2022             5.2        562            406
# 4      McLaren      720S  2021               4        710            568
#
#   0-60 MPH Time (seconds)  Price (in USD)
# 0                       4        101200.0
# 1                     2.8        274390.0
# 2                       3        333750.0
# 3                     3.2        142700.0
# 4                     2.7        298000.0

# %%
#Change data types of necessary columns to floats
sport_car_c = sport_car.astype({"Engine Size (L)": "float", "0-60 MPH Time (seconds)": "float", 
                 "Price (in USD)": "float"})

# %%
sport_car_c.dtypes
# Out:
# Car Make                    object
# model                       object
# Year                         int64
# Engine Size (L)            float64
# Horsepower                  object
# Torque (lb-ft)              object
# 0-60 MPH Time (seconds)    float64
# Price (in USD)             float64
# dtype: object

# %%
#Drop rows with null values from the dataset
sport_car_c= sport_car.dropna()

# %%
# Sort data by Year 
sport_car_year = sport_car_c.sort_values(by = ("Year"))#, ascending = False)
sport_car_year = sport_car_price.reset_index(drop = True)
sport_car_year
# Out:
#           Car Make             Car Model  Year Engine Size (L) Horsepower  \
# 0           Shelby                 Cobra  1965               7        435
# 1    Mercedes-Benz  SLS AMG Black Series  2014             6.2        622
# 2    Mercedes-Benz  SLS AMG Black Series  2014             6.2        622
# 3    Mercedes-Benz               SLS AMG  2015             6.2        583
# 4    Mercedes-Benz               SLS AMG  2015             6.2        622
# ..             ...                   ...   ...             ...        ...
# 943        Porsche           718 Boxster  2022               2        300
# 944      Chevrolet            Camaro ZL1  2022             6.2        650
# 945        Bentley        Continental GT  2022               6        626
# 946      Chevrolet          Corvette Z06  2023             5.5        625
# 947         Nissan                  400Z  2023               3        400
#
#     Torque (lb-ft) 0-60 MPH Time (seconds)  Price (in USD)
# 0              440                     4.2       1000000.0
# 1              468                     3.5        275000.0
# 2              468                     3.5        275000.0
# 3              479                     3.6        221580.0
# 4              468                     3.6        229000.0
# ..             ...                     ...             ...
# 943            280                     4.9         62000.0
# 944            650                     3.5         64000.0
# 945            664                     3.3        214425.0
# 946            650                     2.6         85000.0
# 947            350                       4         40000.0
#
# [948 rows x 8 columns]

# %% [markdown]
# # Transform Dataset 2

# %%
#Remove unwanted columns of data from the car noise dataset
car_noise_new = car_noise[['brand', "model", "spec", "year", "dB_at_idle", "dB_at_50kmh", "dB_at_80kmh", "dB_at_100kmh", "dB_at_120kmh", "dB_at_140kmh"]]

# %%
#Drop all rows with null values 
car_noise_new = car_noise_new.dropna(how="any")
car_noise_new
# Out:
#        brand model            spec    year  dB_at_idle  dB_at_50kmh  \
# 0     Abarth   500   1.4 16v T-Jet  2008.0        47.3         58.2
# 1     Abarth   595    Competizione  2017.0        49.9         65.7
# 2      Acura   MDX          3.5 V6  2013.0        41.7         51.7
# 3      Acura   RDX          3.5 V6  2012.0        43.0         54.4
# 4      Acura    RL          3.7 V6  2009.0        43.6         55.5
# ...      ...   ...             ...     ...         ...          ...
# 1889   Volvo  XC90  T8 Twin Engine  2016.0        37.3         50.3
# 1890   Volvo  XC90            2.0d  2017.0        47.9         64.7
# 1891   Volvo  XC90              T6  2017.0        39.9         55.8
# 1892   Volvo  XC90              D4  2018.0        43.9         53.5
# 1893   Volvo  XC90              D5  2018.0        47.1         55.6
#
#       dB_at_80kmh  dB_at_100kmh  dB_at_120kmh  dB_at_140kmh
# 0            67.0          70.2          72.9          76.0
# 1            69.0          72.3          73.1          75.8
# 2            57.9          61.2          64.0          66.8
# 3            61.5          65.5          67.7          69.9
# 4            63.0          66.9          70.2          73.5
# ...           ...           ...           ...           ...
# 1889         56.6          60.9          65.4          67.8
# 1890         65.5          66.3          67.2          70.6
# 1891         60.0          64.3          65.2          68.6
# 1892         59.1          64.3          66.7          68.8
# 1893         60.9          65.3          67.7          69.8
#
# [1894 rows x 10 columns]

# %%
#Identify the new datatypes of each column 
car_noise_new.dtypes
# Out:
# brand            object
# model            object
# spec             object
# year            float64
# dB_at_idle      float64
# dB_at_50kmh     float64
# dB_at_80kmh     float64
# dB_at_100kmh    float64
# dB_at_120kmh    float64
# dB_at_140kmh    float64
# dtype: object

# %%
#Rename the columns to convert it to US Standard from Metric
car_noise_mph = car_noise_new.copy()
car_noise_mph = car_noise_mph.rename(columns = {"dB_at_50kmh": "db_at_31mph", "dB_at_80kmh": "dB_at_50mph", "dB_at_100kmh": "dB_at_62mph","dB_at_120kmh": "dB_at_75mph", "dB_at_140kmh": "dB_at_87mph"})
car_noise_mph
# Out:
#        brand model            spec    year  dB_at_idle  db_at_31mph  \
# 0     Abarth   500   1.4 16v T-Jet  2008.0        47.3         58.2
# 1     Abarth   595    Competizione  2017.0        49.9         65.7
# 2      Acura   MDX          3.5 V6  2013.0        41.7         51.7
# 3      Acura   RDX          3.5 V6  2012.0        43.0         54.4
# 4      Acura    RL          3.7 V6  2009.0        43.6         55.5
# ...      ...   ...             ...     ...         ...          ...
# 1889   Volvo  XC90  T8 Twin Engine  2016.0        37.3         50.3
# 1890   Volvo  XC90            2.0d  2017.0        47.9         64.7
# 1891   Volvo  XC90              T6  2017.0        39.9         55.8
# 1892   Volvo  XC90              D4  2018.0        43.9         53.5
# 1893   Volvo  XC90              D5  2018.0        47.1         55.6
#
#       dB_at_50mph  dB_at_62mph  dB_at_75mph  dB_at_87mph
# 0            67.0         70.2         72.9         76.0
# 1            69.0         72.3         73.1         75.8
# 2            57.9         61.2         64.0         66.8
# 3            61.5         65.5         67.7         69.9
# 4            63.0         66.9         70.2         73.5
# ...           ...          ...          ...          ...
# 1889         56.6         60.9         65.4         67.8
# 1890         65.5         66.3         67.2         70.6
# 1891         60.0         64.3         65.2         68.6
# 1892         59.1         64.3         66.7         68.8
# 1893         60.9         65.3         67.7         69.8
#
# [1894 rows x 10 columns]

# %%
#Rename common column in sport_car dataframe to facilitate merging
sport_car_c = sport_car_c.rename(columns={"Car Model": "model"})

#Merge both datasets
car_traits = pd.merge(sport_car_c, car_noise_mph, on="model", how="left")
car_traits = car_traits.rename(columns = {"model": "Car Model", "dB_at_idle": "dB_at_Idle"})

#Remove unwanted columns of data from the dataset
car_traits = car_traits[["Car Make", "Car Model", "Year", "Engine Size (L)", "0-60 MPH Time (seconds)", "Price (in USD)", "dB_at_Idle","db_at_31mph", "dB_at_50mph", "dB_at_62mph", "dB_at_75mph", "dB_at_87mph"]]
car_traits
# Out:
#           Car Make Car Model  Year  Engine Size (L)  0-60 MPH Time (seconds)  \
# 0          Porsche       911  2022              3.0                      4.0
# 1          Porsche       911  2022              3.0                      4.0
# 2          Porsche       911  2022              3.0                      4.0
# 3          Porsche       911  2022              3.0                      4.0
# 4          Porsche       911  2022              3.0                      4.0
# ...            ...       ...   ...              ...                      ...
# 1270  Aston Martin   Vantage  2021              4.0                      3.6
# 1271       Bugatti    Chiron  2021              8.0                      2.4
# 1272    Koenigsegg     Jesko  2022              5.0                      2.5
# 1273       McLaren     Senna  2021              4.0                      2.7
# 1274        Pagani    Huayra  2021              6.0                      3.0
#
#       Price (in USD)  dB_at_Idle  db_at_31mph  dB_at_50mph  dB_at_62mph  \
# 0           101200.0        63.7         68.2         71.4         71.8
# 1           101200.0        57.4         66.3         72.1         74.4
# 2           101200.0        61.7         67.1         70.6         71.8
# 3           101200.0        49.7         58.9         65.1         67.0
# 4           101200.0        48.6         59.8         68.8         73.7
# ...              ...         ...          ...          ...          ...
# 1270        146000.0         NaN          NaN          NaN          NaN
# 1271       3000000.0         NaN          NaN          NaN          NaN
# 1272       3000000.0         NaN          NaN          NaN          NaN
# 1273       1000000.0         NaN          NaN          NaN          NaN
# 1274       2600000.0         NaN          NaN          NaN          NaN
#
#       dB_at_75mph  dB_at_87mph
# 0            76.9         82.1
# 1            79.3         84.2
# 2            75.4         79.1
# 3            73.9         80.9
# 4            74.8         76.3
# ...           ...          ...
# 1270          NaN          NaN
# 1271          NaN          NaN
# 1272          NaN          NaN
# 1273          NaN          NaN
# 1274          NaN          NaN
#
# [1275 rows x 12 columns]

# %%
#Drop rows with null dB values from the newly merged dataframe
car_traits = car_traits.dropna(how="any")

#Reset index
car_traits = car_traits.reset_index(drop=True)

#Display dataframe
car_traits
# Out:
#     Car Make Car Model  Year  Engine Size (L)  0-60 MPH Time (seconds)  \
# 0    Porsche       911  2022              3.0                      4.0
# 1    Porsche       911  2022              3.0                      4.0
# 2    Porsche       911  2022              3.0                      4.0
# 3    Porsche       911  2022              3.0                      4.0
# 4    Porsche       911  2022              3.0                      4.0
# ..       ...       ...   ...              ...                      ...
# 573     Ford   Mustang  2021              2.3                      5.3
# 574   Nissan      370Z  2021              3.7                      5.1
# 575   Nissan      370Z  2021              3.7                      5.1
# 576   Nissan      370Z  2021              3.7                      5.1
# 577   Nissan      370Z  2021              3.7                      5.1
#
#      Price (in USD)  dB_at_Idle  db_at_31mph  dB_at_50mph  dB_at_62mph  \
# 0          101200.0        63.7         68.2         71.4         71.8
# 1          101200.0        57.4         66.3         72.1         74.4
# 2          101200.0        61.7         67.1         70.6         71.8
# 3          101200.0        49.7         58.9         65.1         67.0
# 4          101200.0        48.6         59.8         68.8         73.7
# ..              ...         ...          ...          ...          ...
# 573         27205.0        57.3         63.0         66.8         68.0
# 574         30090.0        48.0         59.2         66.3         69.8
# 575         30090.0        47.3         58.2         67.0         70.5
# 576         30090.0        48.1         58.6         65.2         68.5
# 577         30090.0        44.9         65.7         68.5         71.3
#
#      dB_at_75mph  dB_at_87mph
# 0           76.9         82.1
# 1           79.3         84.2
# 2           75.4         79.1
# 3           73.9         80.9
# 4           74.8         76.3
# ..           ...          ...
# 573         72.0         76.1
# 574         73.4         77.1
# 575         72.9         75.6
# 576         71.8         75.2
# 577         74.0         77.8
#
# [578 rows x 12 columns]

# %%
#Create new dataframe using groupby that shows chracteristics on average by brand and model
car_models = car_traits.groupby(["Car Make", "Car Model"]).mean()

#Remove unwanted columns of data from the dataset
car_models = car_models[["Engine Size (L)", "0-60 MPH Time (seconds)", "Price (in USD)", "dB_at_Idle","db_at_31mph", "dB_at_50mph", "dB_at_62mph", "dB_at_75mph", "dB_at_87mph"]]

#Display dataframe
car_models
# Out:
#                               Engine Size (L)  0-60 MPH Time (seconds)  \
# Car Make      Car Model
# Acura         NSX                    3.500000                 2.750000
# Alfa Romeo    4C                     1.750000                 4.150000
# Audi          R8                     5.200000                 3.200000
#               RS5                    2.900000                 3.666667
#               RS7                    4.000000                 3.500000
#               S5                     3.000000                 4.400000
# BMW           M2                     3.000000                 4.058333
#               M4                     3.000000                 3.994737
#               M5                     4.400000                 3.200000
#               i8                     1.500000                 4.200000
# Bentley       Continental GT         5.250000                 3.529167
# Chevrolet     Camaro                 6.200000                 4.000000
#               Corvette               6.200000                 2.800000
# Dodge         Challenger             5.000000                 5.100000
#               Charger                6.200000                 3.300000
#               Viper                  8.400000                 3.300000
# Ford          GT                     3.500000                 2.914706
#               Mustang                2.300000                 5.300000
# Jaguar        F-Type                 3.238095                 4.728571
# Lotus         Evora                  3.500000                 3.800000
# McLaren       570S                   3.800000                 3.056522
#               GT                     4.000000                 3.114286
# Mercedes-Benz AMG GT                 4.000000                 3.800000
#               SL                     3.000000                 4.650000
#               SL                62.400000    66.300000    67.800000
# Nissan        370Z              66.750000    70.025000    73.025000
# Polestar      1                 62.342857    65.367857    67.864286
# Porsche       911               67.853846    70.115385    74.330769
#               Cayman            65.460000    67.620000    72.160000
#               Panamera          61.425000    64.112500    66.787500
# Rolls-Royce   Wraith            56.200000    58.200000    63.500000
# Tesla         Roadster          63.400000    67.600000    68.900000
#
#                               dB_at_87mph
# Car Make      Car Model
# Acura         NSX               73.700000
# Alfa Romeo    4C                83.300000
# Audi          R8                75.320000
#               RS5               70.000000
#               RS7               67.600000
#               S5                73.000000
# BMW           M2                73.200000
#               M4                73.200000
#               M5                71.500000
#               i8                72.300000
# Bentley       Continental GT    69.700000
# Chevrolet     Camaro            74.287500
#               Corvette          80.022222
# Dodge         Challenger        75.533333
#               Charger           72.900000
#               Viper             82.700000
# Ford          GT                65.300000
#               Mustang           76.362500
# Jaguar        F-Type            74.150000
# Lotus         Evora             77.200000
# McLaren       570S              78.800000
#               GT                65.300000
# Mercedes-Benz AMG GT            74.700000
#               SL                70.250000
# Nissan        370Z              76.425000
# Polestar      1                 70.382143
# Porsche       911               78.869231
#               Cayman            77.380000
#               Panamera          69.487500
# Rolls-Royce   Wraith            68.800000
# Tesla         Roadster          70.600000

# %% [markdown]
# # Load Datasets

# %%
#Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
#Create and assign the database to a variable
db = mongo['Sports_Cars']

# %%
#Create and assign a collection to the variable
collection1 = db['car_info']

# %%
#Convert dataframe to a dictionary to insert information into dataframe
info_dict = sport_car_year.to_dict("records")

# Insert dictionary into collection
collection1.insert_many(info_dict)
# Out:
# InsertManyResult([ObjectId('657917a6d90562bf82681c9a'), ObjectId('657917a6d90562bf82681c9b'), ObjectId('657917a6d90562bf82681c9c'), ObjectId('657917a6d90562bf82681c9d'), ObjectId('657917a6d90562bf82681c9e'), ObjectId('657917a6d90562bf82681c9f'), ObjectId('657917a6d90562bf82681ca0'), ObjectId('657917a6d90562bf82681ca1'), ObjectId('657917a6d90562bf82681ca2'), ObjectId('657917a6d90562bf82681ca3'), ObjectId('657917a6d90562bf82681ca4'), ObjectId('657917a6d90562bf82681ca5'), ObjectId('657917a6d90562bf82681ca6'), ObjectId('657917a6d90562bf82681ca7'), ObjectId('657917a6d90562bf82681ca8'), ObjectId('657917a6d90562bf82681ca9'), ObjectId('657917a6d90562bf82681caa'), ObjectId('657917a6d90562bf82681cab'), ObjectId('657917a6d90562bf82681cac'), ObjectId('657917a6d90562bf82681cad'), ObjectId('657917a6d90562bf82681cae'), ObjectId('657917a6d90562bf82681caf'), ObjectId('657917a6d90562bf82681cb0'), ObjectId('657917a6d90562bf82681cb1'), ObjectId('657917a6d90562bf82681cb2'), ObjectId('657917a6d90562bf82681cb3'), ObjectId('657917a6d90562bf82681cb4'), ObjectId('657917a6d90562bf82681cb5'), ObjectId('657917a6d90562bf82681cb6'), ObjectId('657917a6d90562bf82681cb7'), ObjectId('657917a6d90562bf82681cb8'), ObjectId('657917a6d90562bf82681cb9'), ObjectId('657917a6d90562bf82681cba'), ObjectId('657917a6d90562bf82681cbb'), ObjectId('657917a6d90562bf82681cbc'), ObjectId('657917a6d90562bf82681cbd'), ObjectId('657917a6d90562bf82681cbe'), ObjectId('657917a6d90562bf82681cbf'), ObjectId('657917a6d90562bf82681cc0'), ObjectId('657917a6d90562bf82681cc1'), ObjectId('657917a6d90562bf82681cc2'), ObjectId('657917a6d90562bf82681cc3'), ObjectId('657917a6d90562bf82681cc4'), ObjectId('657917a6d90562bf82681cc5'), ObjectId('657917a6d90562bf82681cc6'), ObjectId('657917a6d90562bf82681cc7'), ObjectId('657917a6d90562bf82681cc8'), ObjectId('657917a6d90562bf82681cc9'), ObjectId('657917a6d90562bf82681cca'), ObjectId('657917a6d90562bf82681ccb'), ObjectId('657917a6d90562bf82681ccc'), ObjectId('657917a6d90562bf82681ccd'), ObjectId('657917a6d90562bf82681cce'), ObjectId('657917a6d90562bf82681ccf'), ObjectId('657917a6d90562bf82681cd0'), ObjectId('657917a6d90562bf82681cd1'), ObjectId('657917a6d90562bf82681cd2'), ObjectId('657917a6d90562bf82681cd3'), ObjectId('657917a6d90562bf82681cd4'), ObjectId('657917a6d90562bf82681cd5'), ObjectId('657917a6d90562bf82681cd6'), ObjectId('657917a6d90562bf82681cd7'), ObjectId('657917a6d90562bf82681cd8'), ObjectId('657917a6d90562bf82681cd9'), ObjectId('657917a6d90562bf82681cda'), ObjectId('657917a6d90562bf82681cdb'), ObjectId('657917a6d90562bf82681cdc'), ObjectId('657917a6d90562bf82681cdd'), ObjectId('657917a6d90562bf82681cde'), ObjectId('657917a6d90562bf82681cdf'), ObjectId('657917a6d90562bf82681ce0'), ObjectId('657917a6d90562bf82681ce1'), ObjectId('657917a6d90562bf82681ce2'), ObjectId('657917a6d90562bf82681ce3'), ObjectId('657917a6d90562bf82681ce4'), ObjectId('657917a6d90562bf82681ce5'), ObjectId('657917a6d90562bf82681ce6'), ObjectId('657917a6d90562bf82681ce7'), ObjectId('657917a6d90562bf82681ce8'), ObjectId('657917a6d90562bf82681ce9'), ObjectId('657917a6d90562bf82681cea'), ObjectId('657917a6d90562bf82681ceb'), ObjectId('657917a6d90562bf82681cec'), ObjectId('657917a6d90562bf82681ced'), ObjectId('657917a6d90562bf82681cee'), ObjectId('657917a6d90562bf82681cef'), ObjectId('657917a6d90562bf82681cf0'), ObjectId('657917a6d90562bf82681cf1'), ObjectId('657917a6d90562bf82681cf2'), ObjectId('657917a6d90562bf82681cf3'), ObjectId('657917a6d90562bf82681cf4'), ObjectId('657917a6d90562bf82681cf5'), ObjectId('657917a6d90562bf82681cf6'), ObjectId('657917a6d90562bf82681cf7'), ObjectId('657917a6d90562bf82681cf8'), ObjectId('657917a6d90562bf82681cf9'), ObjectId('657917a6d90562bf82681cfa'), ObjectId('657917a6d90562bf82681cfb'), ObjectId('657917a6d90562bf82681cfc'), ObjectId('657917a6d90562bf82681cfd'), ObjectId('657917a6d90562bf82681cfe'), ObjectId('657917a6d90562bf82681cff'), ObjectId('657917a6d90562bf82681d00'), ObjectId('657917a6d90562bf82681d01'), ObjectId('657917a6d90562bf8268 ...

